# %%
import pandas as pd
import numpy as np

# %%
df_2019_01 = pd.read_csv("JC-201901-citibike-tripdata.csv")
df_2019_02 = pd.read_csv("JC-201902-citibike-tripdata.csv")
df_2019_03 = pd.read_csv("JC-201903-citibike-tripdata.csv")
df_2019_04 = pd.read_csv("JC-201904-citibike-tripdata.csv")
df_2019_05 = pd.read_csv("JC-201905-citibike-tripdata.csv")
df_2019_06 = pd.read_csv("JC-201906-citibike-tripdata.csv")
df_2019_07 = pd.read_csv("JC-201907-citibike-tripdata.csv")
df_2019_08 = pd.read_csv("JC-201908-citibike-tripdata.csv")
df_2019_09 = pd.read_csv("JC-201909-citibike-tripdata.csv")
df_2019_10 = pd.read_csv("JC-201910-citibike-tripdata.csv")
df_2019_11 = pd.read_csv("JC-201911-citibike-tripdata.csv")
df_2019_12 = pd.read_csv("JC-201912-citibike-tripdata.csv")

# %%
df_2019_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df_2019_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df = pd.concat([df_2019_01, df_2019_02, df_2019_03, df_2019_04, df_2019_05, df_2019_06, df_2019_07, df_2019_08, df_2019_09, df_2019_10, df_2019_11, df_2019_12], ignore_index=True)
df.to_csv('2019/2019_concat_test.csv', index = False)
# df.to_csv("")

# %%
bikeid_counts = pd.DataFrame(df['bikeid'].value_counts())

# %%
bikeid_counts.head(20)
# Out:
#        bikeid
# 29286    1134
# 26159    1071
# 29612    1060
# 29210    1059
# 29660    1055
# 29207    1051
# 29640    1046
# 26155    1036
# 29584    1030
# 29221    1026
# 29608    1026
# 29242    1024
# 29209    1023
# 29455    1018
# 26243    1014
# 29272    1013
# 29586    1010
# 26431    1009
# 29598    1006
# 26316     999
